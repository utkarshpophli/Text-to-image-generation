# %% [markdown]
# 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

# %%
import openai
import urllib.request
from PIL import Image
import cv2
from cv2_plt_imshow import cv2_plt_imshow

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    prompt='green grass in river',
    n=1,
    size='1024x1024'
)

# %%
img_response
# Out:
# <OpenAIObject at 0x1ad4092cdd0> JSON: {
#   "created": 1681980645,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-1y24b1i0C4SFIRUISrdGxpFK/user-QebfltNSSnMel5onar32oxh6/img-NIPW5uTxmfyJ5R0BA5bcyIas.png?st=2023-04-20T07%3A50%3A45Z&se=2023-04-20T09%3A50%3A45Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-20T05%3A35%3A29Z&ske=2023-04-21T05%3A35%3A29Z&sks=b&skv=2021-08-06&sig=I%2BP5j4xzzLxEu8RpuEvF1c80gWvBUCKfZR%2BrMcdsVr4%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-1y24b1i0C4SFIRUISrdGxpFK/user-QebfltNSSnMel5onar32oxh6/img-NIPW5uTxmfyJ5R0BA5bcyIas.png?st=2023-04-20T07%3A50%3A45Z&se=2023-04-20T09%3A50%3A45Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-20T05%3A35%3A29Z&ske=2023-04-21T05%3A35%3A29Z&sks=b&skv=2021-08-06&sig=I%2BP5j4xzzLxEu8RpuEvF1c80gWvBUCKfZR%2BrMcdsVr4%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-1y24b1i0C4SFIRUISrdGxpFK/user-QebfltNSSnMel5onar32oxh6/img-NIPW5uTxmfyJ5R0BA5bcyIas.png?st=2023-04-20T07%3A50%3A45Z&se=2023-04-20T09%3A50%3A45Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-20T05%3A35%3A29Z&ske=2023-04-21T05%3A35%3A29Z&sks=b&skv=2021-08-06&sig=I%2BP5j4xzzLxEu8RpuEvF1c80gWvBUCKfZR%2BrMcdsVr4%3D'

# %%
urllib.request.urlretrieve(img_url, 'image.png')
# Out:
# ('image.png', <http.client.HTTPMessage at 0x1ad409d7d90>)

# %%
img = cv2.imread('image.png')
cv2_plt_imshow(img)
